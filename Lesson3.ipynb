# %% [markdown]
# Задание 1
#
# Получите ответ на следующие вопросы (с помощью pandas):
#
# 1). Сколько всего жанров и какие они?
#
# 2). Сколько суммарно байт весят все приложения жанра Finance?
#
# 3). Сколько всего бесплатных приложений, у которых рейтинг юзеров больше трёх?
#
# 4). Есть ли приложения, которые стоят больше 100 долларов?

# %%
#1 
import pandas as pd
data = pd.read_csv('./app-store-apple-data-set-10k-apps/AppleStore.csv')
num_genre = len(data['prime_genre'])
genre_set = set(data['prime_genre'])
print(f'число жанров : {num_genre}\n')
print(f'Жанры : {genre_set}\n')
#2
print(f"Сколько суммарно байт весят все приложения жанра Finance : \n{data[data['prime_genre'] == 'Finance'].groupby('prime_genre')['size_bytes'].sum()}\n")
#3
print(f"Сколько всего бесплатных приложений, у которых рейтинг юзеров больше трёх :\n{len(data[ (data['price'] == 0) & (data['user_rating'] > 3)])}")
#4
print(f"Какие есть валюты : {set(data['currency'])}") 
#значит, конвертировать не придётся в доллары что-то там
if len(data[ (data['price'] > 100)]) > 0:
    print (f"есть приложения, что стоят > 100 долларов, их : {len(data[ (data['price'] > 100)])} шт")
else:
    print ('нет приложений, что стоят > 100 долларов')
# Out:
# число жанров : 7197
#
# Жанры : {'Utilities', 'Reference', 'Productivity', 'Lifestyle', 'Games', 'Music', 'Health & Fitness', 'News', 'Catalogs', 'Navigation', 'Entertainment', 'Finance', 'Shopping', 'Photo & Video', 'Social Networking', 'Travel', 'Weather', 'Medical', 'Food & Drink', 'Book', 'Education', 'Sports', 'Business'}
#
# Сколько суммарно байт весят все приложения жанра Finance :
# prime_genre
# Finance    8136529366
# Name: size_bytes, dtype: int64
#
# Сколько всего бесплатных приложений, у которых рейтинг юзеров больше трёх :
# 2944
# Какие есть валюты : {'USD'}
# есть приложения, что стоят > 100 долларов, их : 2 шт

# %%
data
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# ...          ...         ...
# 7192       11081  1187617475
# 7193       11082  1187682390
# 7194       11087  1187779532
# 7195       11089  1187838770
# 7196       11097  1188375727
#
#                                              track_name  size_bytes currency  \
# 0                                       PAC-MAN Premium   100788224      USD
# 1                             Evernote - stay organized   158578688      USD
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts   100524032      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...   128512000      USD
# 4                                                 Bible    92774400      USD
# ...                                                 ...         ...      ...
# ...

# %%
data[data['prime_genre'] == 'Finance']
# Out:
#       Unnamed: 0          id                                     track_name  \
# 6              7   283646709         PayPal - Send and request money safely
# 13            14   284847138               Bank of America - Mobile Banking
# 67            76   298867247                                  Chase Mobile℠
# 73            83   300238550  Mint: Personal Finance, Budget, Bills & Money
# 80            91   301724680                                   Citi Mobile®
# ...          ...         ...                                            ...
# 6110        8650  1113936701                             创客金融-高收益银行存管投资理财平台
# 6207        8863  1117825020                           妙资理财（九周年版)-高收益理财投资平台
# 6208        8864  1117825025                      妙资理财-福利版（年化14.8%注册送1万体验金）
# 6906       10307  1156875272                                          Suica
# 7118       10866  1177384028                          紫马财行理财精英版—安全可靠的投资理财平台
#
# ...

# %%
import numpy as np
np.array(data['size_bytes'])
type(data['size_bytes'].values)
# Out:
# numpy.ndarray
